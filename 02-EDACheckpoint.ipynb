# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# - Harvey Sandhu - Conceptualization, background research
# - Kyle Wu - Conceptualization, data curation
# - Connor Wu - Conceptualization, data curation
# - Adrianne See - Conceptualization, project administration
# - Teddy Nguyen - Conceptualization, project administration

# %% [markdown]
# # Research Question

# %% [markdown]
# Did the characteristics of passengers on the Titanic, such as ticket class, age, and gender, affect an individual's survivability?
# - Considering the women and children first rule, how does that correlate with survival statistics, specifically looking at the "adult male" column of the data?
# - Did richer passengers, i.e. those who purchased higher deck or class tickets for higher prices have a higher survival rate than those who purchased cheaper tickets?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The RMS Titanic was a British ocean liner infamous for its sinking after colliding with an iceberg on April 15, 1912, resulting in ~1500 people out of the 2200+ passengers dying from the wreck. The data set we are analyzing includes information on 891 passengers, including their passenger class, age, sex, and their accompaniment. Even though considered a catastrophic event, which are usually described as random or indiscriminate, research consistently shows that social factors shape survival outcomes. Disaster research reveals that survival is influenced by social factors, such as socioeconomic status (SES), age, and gender, rather than pure chance.
#
# Similar studies:
#
# A paper from Bowdoin College highlights that the Titanic, like many disasters, had "differential effects" in which survival and suffering were unequally distributed across class, age, and gender lines. It emphasized that first-class passengers had a survival rate of about 62%, compared to 41% in second class and only 25% in third class (Bowdoin), showcasing stark SES differences and translation to better survival hood. The aper theorizes that the higher status translates into better access to information, lifeboats, and life-saving opportunities.  The paper also incorporates a diagram of the Titanic, showcasing that third class passengers were located lower and at the ends of the boat, second class lower middle, and first class upper middle. This diagram allows for the inference that if the boat were sinking, the first-class passengers had more time to reach life-saving measures. The same piece showcases that women and children had much higher rates of survival, with 75 and 50 percent, respectively, while men only had about 20% survival. This follows suit with the order Captain E.J. Smith gave to officers, "women and children first." The paper also mentions that certain officers interpreted these orders differently, with Officer Lightroller taking the order to mean women and children only, lowering lifeboats even before full capacity to prioritize women and children's survival.
#
# In a more formal analysis, Frey, Heggli, and Osterloh used individual-level Titanic data to test how economic resources, age, and gender affected the probability of survival. Aside from reconfirming that class and gender played a large role in the probability of survival, they showed age mattered as well. People in their "prime" (ages around 15-35) were more likely to survive than older passengers (Frey et al.), suggesting that physical mobility and stamina interacted with the other categories to shape outcomes.
#
# A study similar to our proposed topic, but with a slightly different data set, concluded that gender was, in fact, the key determining factor in survivability.1 Because this is a historical topic, we can safely assume that there will be no issues with outdated data or analysis, but the data sets being analyzed may have varying results. Despite being the same size, with 891 passengers, the data set we are analyzing has some additional information that may reveal more nuance in the death statistics. Additionally, the individuals may be different, meaning a different population of the Titanic survivors was sampled.
#
# An article from the NIH states that, despite the widespread belief of prioritizing women and children in maritime accidents, women in fact have a significant survival disadvantage in these situations 2. It further asserts that despite the survival rate of women on the Titanic being significantly higher, in the grander scheme of maritime accidents reflects the opposite.
#
# Citations:
#
# "Analysis of Titanic Survival Data", ttsteiger.github.io/projects/titanic_report.html. Accessed 4 Feb. 2026.
#
# Elinder, Mikael, and Oscar Erixson. "Gender, Social Norms, and Survival in Maritime Disasters." Proceedings of the National Academy of Sciences of the United States of America, U.S. National Library of Medicine, 14 Aug. 2012, pmc.ncbi.nlm.nih.gov/articles/PMC3421183/.
#
# Bowdoin. "Disproportionate Devastation | Titanic." Bowdoin, 2020, courses.bowdoin.edu/history-2203-fall-2020-kmoyniha/reflection/.
#
# Frey, Bruno S, et al. "Surviving the Titanic Disaster: Economic, Natural and Social Determinants." Escholarship.org, Feb. 2009, escholarship.org/uc/item/6h24b1vt.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# After deliberation, we predict that Gender and Class will have had the most effect on any individual on the Titanic’s survival, and consequently the associated significance statistics and weight on any model will be largest.
#
# For the gender characteristic, we believe that the use of “Women and Children first” or the WCF order, during the Titanic’s sinking had a major positive impact on the survival rates of Females and Passengers that would fit the “Children” characteristic.
#
# For the socioeconomic aspect, we believe that the type of ticket, reflecting the class of the individual who purchased the ticket, will have a positive correlation with their associated survival rate. This, we agreed on, will be due to a number of factors, primarily a prevailing classism present during the time period, as well as a number of physical characteristics such as the location of second and third class passengers being lower on the Titanic compared to first class passengers.
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Dataset Name: Titanic Dataset
#
# Link to the dataset: https://www.kaggle.com/datasets/shraddha4ever20/titanic-datset
#
# Number of observations: 891
#
# Number of variables: 15
#
# Description of the variables most relevant to this project: 13
#
# Descriptions of any shortcomings this dataset has with respect to the project: This dataset has some null values for the passenger ages. It also contains some repeated data in different formats (e.g., passenger class in both numeric and string formats). While this is not inherently a downside, it forces us to decide which format works better for our analysis purposes.
#
# The primary dataset we selected from Kaggle is well-suited for our research question since it includes individual-level information on survival, age, sex, ticket class, and fare for 891 passengers. This allows us to look at how socioeconomic status (class and fare), age, and gender all influenced survival outcomes. Although this dataset represents a portion rather than the full passenger and crew list, it is large enough to support meaningful statistical analysis while remaining manageable for our project. Each row in the kaggle dataset corresponds to a single passenger and includes variables such as survival status (0 = did not survive, 1 = survived), passenger class (which we treate as a SES indicator), sex (nale/female), age, fare (ticket price, another SES indicator), and a few additional identifiers which wont be used but could be linked to external sources for deeper context.
#
# In an ideal scenario, we would work with a complete manifest that includes all passengers and crew, precise cabin locations, lifeboat assignments, and verified socioeconomic status indicators directly sourced from the original passenger documents. That dataset would have helped to reduce sampling bias and enable more detailed modeling of how physical location on the ship and social status affected the changes of reaching a lifeboat. Our current Kaggle dataset approximates this ideal by providing demographic and class variables, but is limited by missing ages and the absence of detailed location or income information.
#
# There are a few complementary real-world datasets and sources that could help us move closer to this scenario. For example, the Safe-DS Titanic dataset includes cabin numbers, which would allow us to incorporate more precise spatial information about where passengers were located on the ship at the time of impact. Wikipedia's compiled passenger list and summaries provide additional attributes that can help us, such as nationality and, in some cases, lifeboat assignment. Nationality can be used to explore potential discrimination or differences in survival by country of origin, while lifeboat assignments can help reconstruct evacuation patterns. Together, these sources could be integrated with the Kaggle dataset to create a more complete picture, but our core analysis for how class, age, and gender influenced survival, which the Kaggle dataset already holds the essential variables we need.
#
# "Titanic - Safe-DS Datasets." Safeds.com, 2026, datasets.safeds.com/en/stable/datasets/titanic/. Accessed 16 Feb. 2026.
#
# "Passengers of the Titanic." Wikipedia, 12 Feb. 2021, en.wikipedia.org/wiki/Passengers_of_the_Titanic.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=177omQn-AJbkKwuR4hlVE7njbwOywvjjk', 'filename':'titanic.csv'},
]

get_data.get_raw(datafiles, destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.39s/it]
# Successfully downloaded: titanic.csv

# %% [markdown]
# ### Titanic Passenger Survival and Characteristics
#
# pclass – Passenger class (1st, 2nd, 3rd),
#
# sex – Gender of passenger
#
# age – Age in years
#
# sibsp – Number of siblings/spouses aboard
#
# parch – Number of parents/children aboard
#
# fare – Ticket fare in dollars
#
# who – Man, woman, or child
#
# adult_male – Boolean indicator for adult male
#
# deck – Deck level (where available) (A, B, C, D, E, null)
#
# embark_town – Town of embarkation in string format (Cherbourg, Queenstown, or Southampton)
#
# alive – Survival status (Yes/No)
#
# alone – Boolean indicator if passenger was alone
#
#
# The dataset is not composed of the entire Titanic manifest, as it only has 891 of the 1317 passengers. This is not proof of a biased dataset, but it is not fully representative and/or entirely historically accurate to the original list.
#
#
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %%
import pandas as pd
import os

df = pd.read_csv('data/00-raw/titanic.csv')

print("Shape:", df.shape)
print("Data types:", df.dtypes)

missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)
print("Missing values:", pd.DataFrame({'count': missing, 'pct': missing_pct})[missing > 0])

# drop rows where Age is missing
df = df.dropna(subset=['age'])

# Flag fare outliers
fare_cutoff = df['fare'].mean() + 3 * df['fare'].std()
print(f"Fare outliers (>{fare_cutoff:.2f}): {len(df[df['fare'] > fare_cutoff])} rows")

print("Summary stats:", df[['survived', 'pclass', 'age', 'fare']].describe().round(2))
print("Final shape:", df.shape)

os.makedirs('data/02-processed', exist_ok=True)
df.to_csv('data/02-processed/titanic_clean.csv', index=False)
print("Saved to data/02-processed/titanic_clean.csv")
# Out:
# Shape: (891, 15)
# Data types: survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object
# Missing values:              count    pct
# age            177  19.87
# embarked         2   0.22
# deck           688  77.22
# embark_town      2   0.22
# Fare outliers (>193.45): 18 rows
# Summary stats:        survived  pclass     age    fare
# count    714.00  714.00  714.00  714.00
# mean       0.41    2.24   29.70   34.69
# std        0.49    0.84   14.53   52.92
# min        0.00    1.00    0.42    0.00
# 25%        0.00    1.00   20.12    8.05
# 50%        0.00    2.00   28.00   15.74
# 75%        1.00    3.00   38.00   33.38
# ...

# %% [markdown]
# ### Dataset #2
#  as above, add any more copies of this that you need to given how many datasets you have

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Setup

# %%
# Move and standardize import statements here

## import seaborn for plotting
import seaborn as sns
sns.set(font_scale=1.2, style="white")

# import matplotlib for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style

# set plotting size parameter
plt.rcParams['figure.figsize'] = (12, 5)

# import ANOVA
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd as tukeyhsd
from scipy.stats import f_oneway as anova

# improve resolution
# %config InlineBackend.figure_format ='retina'

# import cleaned dataset
df = pd.read_csv('data/02-processed/titanic_clean.csv')

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Section 1 of EDA - Testing Columnwise correlation, dimensionality, and summary statistics
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %% [markdown]
# #### Teddy - Survivor Age

# %% [markdown]
# This section seperates the data into multiple categories, survivors, nonsurvivors, female survivors, male survivors, female nonsurvivors and male non survivors. Using that data we show their size and mean age, then we plot it.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
import seaborn as sns
import os

titanic = pd.read_csv('data/02-processed/titanic_clean.csv')

# Has a lot of nil values and we don't need it
titanic = titanic.drop(['deck'], axis=1)
titanic = titanic.dropna(subset=['age'])

nonsurvivors, survivors = [x for _, x  in titanic.groupby(titanic['survived'] == 1)]


female_survivors, male_survivors = [x for _, x  in survivors.groupby(titanic['sex'] == 'male')]
female_nonsurvivors, male_nonsurvivors = [x for _, x  in nonsurvivors.groupby(titanic['sex'] == 'male')]

# Print all the data
print("")
print("Total Passengers (With Valid Age): ", titanic.shape[0])
print("")
print("Num Male Survivors: ", male_survivors.shape[0])
print("Num Female Survivors: ", female_survivors.shape[0])
print("Num Male Nonsurvivors: ", male_nonsurvivors.shape[0])
print("Num Female Nonsurvivors: ", female_nonsurvivors.shape[0])
print("")
print("Average Male Survivors Age: ", male_survivors['age'].mean().round(2))
print("Average Female Survivors Age: ", female_survivors['age'].mean().round(2))
print("Average Male Nonsurvivors Age: ", male_nonsurvivors['age'].mean().round(2))
print("Average Female Nonsurvivors Age: ", female_nonsurvivors['age'].mean().round(2))
print("")
print("Survivor Stats: ", survivors[["age"]].describe().round(2))
print("")
print("Nonsurvivor Stats: ", nonsurvivors[["age"]].describe().round(2))
print("")

# Box plot of age, sex and whether the person survied or not
survivor_plot = sns.boxplot(data=titanic, x='age', y="alive", hue='sex')
survivor_plot.set_title("Survivor vs Nonsurvivor data")
# Out:
# Total Passengers (With Valid Age):  714
#
# Num Male Survivors:  93
# Num Female Survivors:  197
# Num Male Nonsurvivors:  360
# Num Female Nonsurvivors:  64
#
# Average Male Survivors Age:  27.28
# Average Female Survivors Age:  28.85
# Average Male Nonsurvivors Age:  31.62
# Average Female Nonsurvivors Age:  25.05
#
# Survivor Stats:            age
# count  290.00
# mean    28.34
# std     14.95
# min      0.42
# 25%     19.00
# 50%     28.00
# 75%     36.00
# max     80.00
#
# Nonsurvivor Stats:            age
# count  424.00
# mean    30.63
# std     14.17
# min      1.00
# 25%     21.00
# 50%     28.00
# 75%     39.00
# max     74.00
# Text(0.5, 1.0, 'Survivor vs Nonsurvivor data')

# %% [markdown]
# We do a Chi-Squared Test to see if there was a relationship between male and female survivalship. We get a very low p-value which tells us to reject the null hypothesis which is to say there is a relationship between gender and survivalship.
#
# Then we do a t-test to see if age influenced survivalship. And from the p-value we can say age influences survivalship.

# %%
# Chi squared test to test relationship between male and female survivalship
chi_squared_test = stats.chi2_contingency(
    [[male_survivors.shape[0], male_nonsurvivors.shape[0]], [female_survivors.shape[0], female_nonsurvivors.shape[0]]]
)
print("\nChi-Squared Test:")
print("Statistic: ", chi_squared_test.statistic)
print("P-Value: ", chi_squared_test.pvalue)

# T-Test to test the relationship between age and survivalship
ttest = stats.ttest_ind(survivors["age"], nonsurvivors["age"])
print("\nT-Test:")
print("Statistic: ", ttest.statistic)
print("P-Value: ", ttest.pvalue)
# Out:
# Chi-Squared Test:
# Statistic:  205.0258275285591
# P-Value:  1.6716678441395054e-46
#
# T-Test:
# Statistic:  -2.06668694625381
# P-Value:  0.03912465401348249

# %% [markdown]
# #### Harvey - Alone vs Not Alone

# %% [markdown]
# In this section, we directly look at whether passengers traveling alone had different survival outcomes  than passengers traveling with family/spouse. We can summarize the survival rates and raw counts by the dataset's Alone indicator, then visualize both the rate difference and composition of outcomes for survived vs not survived. This allows us to establish the baseline relationship we can later check for pairing it with class, sex, and age.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Always make sure figures directory exists BEFORE saving
os.makedirs("figures", exist_ok=True)

# Load processed data (do NOT reload raw data here)
df = pd.read_csv("data/02-processed/titanic_clean.csv")

# Quick sanity checks
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

# Ensure survived is 0/1
df["survived"] = df["survived"].astype(int)

# Ensure alone is boolean (handles True/False, 0/1, strings)
df["alone"] = df["alone"].astype(str).str.lower().map({"true": True, "false": False, "1": True, "0": False})
df["alone"] = df["alone"].fillna(False).astype(bool)

df[["survived", "alone"]].head()
# Out:
# Shape: (714, 15)
# Columns: ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']
#    survived  alone
# 0         0  False
# 1         1  False
# 2         1   True
# 3         1  False
# 4         0   True

# %% [markdown]
# 1: load + setup + sanity checks
#
# This block loads the processed dataset so our EDA is reproducible. It also ensured that survived is stored as a 0/1 integer and that alone is consistently interpreted as a boolean. These checks prevent plotting and groupby errors caused by mixed datatypes and can help ensure our later caalculations are valid.

# %%
survival_by_alone = (
    df.groupby("alone")["survived"]
      .agg(total="count", survived="sum", survival_rate="mean")
      .reset_index()
)

survival_by_alone["label"] = survival_by_alone["alone"].map({True: "Alone", False: "Not Alone"})
survival_by_alone = survival_by_alone.sort_values("alone")  # Not Alone first

# Add useful effect sizes
rate_not = survival_by_alone.loc[survival_by_alone["alone"] == False, "survival_rate"].iloc[0]
rate_alone = survival_by_alone.loc[survival_by_alone["alone"] == True, "survival_rate"].iloc[0]
survival_by_alone["survival_rate"] = survival_by_alone["survival_rate"].round(4)

print("Survival summary (alone vs not alone):")
display(survival_by_alone[["label", "total", "survived", "survival_rate"]])

print(f"Risk difference (Not Alone - Alone): {rate_not - rate_alone:.3f}")
print(f"Relative risk (Not Alone / Alone): {(rate_not / rate_alone) if rate_alone > 0 else np.nan:.3f}")
# Out:
# Survival summary (alone vs not alone):
#        label  total  survived  survival_rate
# 0  Not Alone    310       160         0.5161
# 1      Alone    404       130         0.3218
# Risk difference (Not Alone - Alone): 0.194
# Relative risk (Not Alone / Alone): 1.604

# %% [markdown]
# 2: Core summary table + effect sizes
#
# The table produced is a summary table grouped by alone showing:
# * Total passengers in each group
# * survived count

# %%
fig, ax = plt.subplots(figsize=(7, 5))

labels = survival_by_alone["label"].tolist()
rates = survival_by_alone["survival_rate"].tolist()
totals = survival_by_alone["total"].tolist()

bars = ax.bar(labels, rates, edgecolor="white")

ax.set_ylim(0, 1)
ax.set_ylabel("Survival Rate")
ax.set_title("Titanic Survival Rate: Alone vs Not Alone")
ax.spines[["top", "right"]].set_visible(False)

for bar, rate, n in zip(bars, rates, totals):
    ax.text(bar.get_x() + bar.get_width()/2, rate + 0.02,
            f"{rate:.1%}\n(n={n})", ha="center", va="bottom", fontsize=11)

plt.tight_layout()
plt.savefig("figures/eda_alone_survival_rate.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# 3: Bar chart: survival rate with sample sizes
#
# The plot produced: bar chart of survival rate for "Not Alone" vs "Alone" with annotations showing percentage and n.
#
# This figure answers the question: Which group had a higher probability of survival?

# %%
fig, ax = plt.subplots(figsize=(7, 5))

survived_counts = survival_by_alone["survived"].tolist()
not_survived_counts = (survival_by_alone["total"] - survival_by_alone["survived"]).tolist()
x = np.arange(len(labels))

ax.bar(x, survived_counts, label="Survived", edgecolor="white")
ax.bar(x, not_survived_counts, bottom=survived_counts, label="Did Not Survive", edgecolor="white")

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylabel("Number of Passengers")
ax.set_title("Passenger Counts by Survival and Alone Status")
ax.legend()
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("figures/eda_alone_counts_stacked.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# 4: Stacked bar chart: outcome composition
#
# Plot produced: stacked bars showing counts of Survived and Did not survive for each alone catagory.
#
# While the previous plot focuses on probability, this plot looks at raw outcomes. It shows how many passengers survived and died in each group, which helps interpret the magnitutde of the difference and prevents over focusin gon the rate alone.

# %% [markdown]
# Section 2: Confounding & Subgroup Patterns (Sex, Class, Age)
#
# The relationsip between being alone and survival may be influenced by other facotrs such as gender, passenger class, and age. For example, if people traveling alone were more likley to be adult men or third-class passengers, then a survival difference might reflect those structural factors rather than "alone status" itself. In this section we examine wether "alone status" is unevenly distributed across key groups.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data/02-processed/titanic_clean.csv")
df["survived"] = df["survived"].astype(int)
df["alone"] = df["alone"].astype(str).str.lower().map({"true": True, "false": False, "1": True, "0": False})
df["alone"] = df["alone"].fillna(False).astype(bool)

sex_alone = (
    df.groupby(["sex", "alone"])["survived"]
      .agg(total="count", survival_rate="mean")
      .reset_index()
)

sex_alone["alone_label"] = sex_alone["alone"].map({True: "Alone", False: "Not Alone"})

print("Survival rate by sex and alone status:")
display(sex_alone.sort_values(["sex", "alone"]))

# Pivot for safe plotting (won't crash if a cell is missing)
sex_piv = sex_alone.pivot(index="sex", columns="alone_label", values="survival_rate").fillna(0)

fig, ax = plt.subplots(figsize=(7, 5))
sex_piv.plot(kind="bar", ax=ax, edgecolor="white")

ax.set_ylim(0, 1)
ax.set_ylabel("Survival Rate")
ax.set_title("Survival Rate by Sex, split by Alone Status")
ax.legend(title="")
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("figures/eda_alone_by_sex.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Survival rate by sex and alone status:
#       sex  alone  total  survival_rate alone_label
# 0  female  False    161       0.732919   Not Alone
# 1  female   True    100       0.790000       Alone
# 2    male  False    149       0.281879   Not Alone
# 3    male   True    304       0.167763       Alone

# %% [markdown]
# 1: Sruvival rate by sex and alone
#
# Table produced: Survival rate and counts grouped by sex and alone
#
# Plot produced: grouped bar chart showing survival rate split alone status within each sex.
#
# This block checks whether the alone effect is consistent within male and female passengers.

# %%
class_alone = (
    df.groupby(["pclass", "alone"])["survived"]
      .agg(total="count", survival_rate="mean")
      .reset_index()
)

class_alone["alone_label"] = class_alone["alone"].map({True: "Alone", False: "Not Alone"})

print("Survival rate by class and alone status:")
display(class_alone.sort_values(["pclass", "alone"]))

class_piv = class_alone.pivot(index="pclass", columns="alone_label", values="survival_rate").fillna(0)

fig, ax = plt.subplots(figsize=(7, 5))
class_piv.loc[[1,2,3]].plot(kind="bar", ax=ax, edgecolor="white")

ax.set_ylim(0, 1)
ax.set_ylabel("Survival Rate")
ax.set_title("Survival Rate by Passenger Class, split by Alone Status")
ax.set_xticklabels(["1st", "2nd", "3rd"], rotation=0)
ax.legend(title="")
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("figures/eda_alone_by_class.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Survival rate by class and alone status:
#    pclass  alone  total  survival_rate alone_label
# 0       1  False    100       0.710000   Not Alone
# 1       1   True     86       0.593023       Alone
# 2       2  False     80       0.637500   Not Alone
# 3       2   True     93       0.344086       Alone
# 4       3  False    130       0.292308   Not Alone
# 5       3   True    225       0.208889       Alone

# %% [markdown]
# 2: Survival rate by passenger class and alone
#
# Table produced: survival rate and counts grouped by pclass and alone.
#
# Plot produced: grouped bar chart showing survival rate split by alone status within each pasenger class (1st, 2nd, 3rd).
#
# Passenger class is a key proxy for socioeconomic status and physical access to lifeboats. This block checks whehter being alone  matters euqally across classes or whther the pattern is mostly driven by the strong survival differences across classes. The plot helps identify whether class modifies the alone survival relationship.

# %%
age_summary = (
    df.groupby("alone")["age"]
      .agg(n="count",
           median="median",
           q1=lambda x: np.percentile(x, 25),
           q3=lambda x: np.percentile(x, 75))
      .reset_index()
)
age_summary["label"] = age_summary["alone"].map({True: "Alone", False: "Not Alone"})

print("Age summary by alone status (median, IQR):")
display(age_summary[["label", "n", "median", "q1", "q3"]].round(2))

ages_not = df.loc[df["alone"] == False, "age"].dropna()
ages_alone = df.loc[df["alone"] == True, "age"].dropna()

fig, ax = plt.subplots(figsize=(7, 5))
ax.boxplot([ages_not, ages_alone], labels=["Not Alone", "Alone"], showfliers=False)

ax.set_ylabel("Age")
ax.set_title("Age Distribution: Alone vs Not Alone (boxplot)")
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("figures/eda_alone_age_boxplot.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Age summary by alone status (median, IQR):
#        label    n  median    q1    q3
# 0  Not Alone  310    26.0  16.0  37.0
# 1      Alone  404    29.5  22.0  39.0
# C:\Users\Sandh\AppData\Local\Temp\ipykernel_9824\2927880280.py:18: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([ages_not, ages_alone], labels=["Not Alone", "Alone"], showfliers=False)

# %% [markdown]
# 3: Age distribution comparison: median/IQR + boxplot
#
# Table produced: age summary for Alone vs Not alone including median and IQR (Q1-Q3).
# Plot produced: boxplot comparing age distributions for Alone vs Not Alone.
#
# Age is often skewed and can include outliers, so we use median and IQR instead of relying on mean. This block answers if passengers are travelling alone systematically older/younger? if "alone" passengers tend to be older adult males it could partially explain survival differences.

# %%
alone_rate_sex = pd.crosstab(df["sex"], df["alone"], normalize="index")
alone_rate_sex.columns = ["Not Alone", "Alone"]

alone_rate_class = pd.crosstab(df["pclass"], df["alone"], normalize="index")
alone_rate_class.columns = ["Not Alone", "Alone"]

print("Proportion alone within each sex:")
display(alone_rate_sex.round(3))

print("Proportion alone within each passenger class:")
display(alone_rate_class.round(3))

fig, ax = plt.subplots(figsize=(7,5))
alone_rate_class["Alone"].plot(kind="bar", ax=ax, edgecolor="white")
ax.set_title("Proportion of Passengers Traveling Alone by Class")
ax.set_ylabel("Proportion Alone")
ax.set_ylim(0, 1)
ax.set_xticklabels(["1st", "2nd", "3rd"], rotation=0)
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("figures/eda_alone_rate_by_class.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Proportion alone within each sex:
#         Not Alone  Alone
# sex
# female      0.617  0.383
# male        0.329  0.671
# Proportion alone within each passenger class:
#         Not Alone  Alone
# pclass
# 1           0.538  0.462
# 2           0.462  0.538
# 3           0.366  0.634

# %% [markdown]
# 4: Counfounding check: is alone status unevenly distributed?
#
# Tables produced:
# * Proportion alone within each sex (row-normalized crosstab)
# * Proportion alone within each passenger class (row-normalized crosstab)
#
# Plot produced: bar chart of proportion traveling alone by passenger class.
#
# This block evaluates whether "alone status" is random os systematically related to other important variables. If some groups such as third class have much higher rates of traveling alone, then alone status in likely counfounded with class and potentially with survival.|

# %% [markdown]
# #### Kyle - Preliminary Investigation into ticket 'class' and survival rates

# %% [markdown]
# To find relationship between passenger class had a significant correlation with surivival rates, which implies possible correlation with socio-economic class, we will be performing EDA on passenger class (pclass [1, 2, 3]) and survival rate (survived [0, 1])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/02-processed/titanic_clean.csv')

print(df['survived'].value_counts())
print(df['pclass'].value_counts().sort_index())
# Out:
# survived
# 0    424
# 1    288
# Name: count, dtype: int64
# pclass
# 1    184
# 2    173
# 3    355
# Name: count, dtype: int64

# %% [markdown]
# The dataset holds 714 passengers — a clean subset of the original 891-row dataset with incomplete records removed. Overall, only 40.6% survived. The class breakdown is notably uneven: Third Class passengers account for 49.7% of all passengers (355 of 714), nearly as many as First and Second combined. This is important context, as any aggregate count will be naturally dominated by Third Class, so we should work in rates rather than raw counts. The deck column is missing for 96% of passengers and won't be useful for this analysis. Additionally, decks were shared between the classes, so we will be omitting deck level from this analysis completely.

# %% [markdown]
# ##### Survival Rate by Class — Counts and Bar Plot

# %%
survival_by_class = df.groupby('pclass')['survived'].agg(['mean', 'sum', 'count'])
survival_by_class.columns = ['survival_rate', 'survivors', 'total']
survival_by_class['survival_rate'] = survival_by_class['survival_rate'].round(3)
print(survival_by_class)

survival_by_class['survival_rate'].plot(kind='bar', color=['gold', 'silver', '#cd7f32'])
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.show()
# Out:
#         survival_rate  survivors  total
# pclass
# 1               0.656        122    186
# 2               0.480         83    173
# 3               0.239         85    355

# %% [markdown]
# First, we'll look at the raw rates for survival rate per class, in percentages and in a bar plot. With this, we can immediately see that First class has both a higher survival rate and around 40 more total survivors than Second and Third class each, while having close to the same number of passengers as Second class and roughly half as many passengers as Third class. First Class passengers survived at a rate of 65.6%, which is nearly nearly 2.7× higher than Third Class passengers at 23.9%.
#
# This striking difference shows how class may have significantly shaped survival odds.

# %% [markdown]
# ##### Crosstab Heatmap of Survival Data

# %%
ct = pd.crosstab(df['pclass'], df['survived'], normalize='index')
sns.heatmap(ct, annot=True, fmt='.2%', cmap='RdYlGn')
plt.title('Survival Rate by Class (% of each class)')
plt.show()

# %% [markdown]
# Next, we'll use a heatmap to see how the ratio of survival was affected in each class. Second class stands out as the most even split, with roughly half surviving and half not. First and Third class have inverted patterns, with Third class being the most dramatic split.

# %% [markdown]
# ##### Is the Correlation Statistically Significant?

# %%
from scipy.stats import chi2_contingency
import numpy as np

ct_raw = pd.crosstab(df['pclass'], df['survived'])
chi2, p, dof, expected = chi2_contingency(ct_raw)

n = ct_raw.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct_raw.shape) - 1)))

print(f"Chi2:      {chi2:.2f}")
print(f"P-value:   {p:.20f}")
# Out:
# Chi2:      92.90
# P-value:   0.00000000000000000001

# %% [markdown]
# Because both pclass and survived are categorical variables, we'll use the Chi-Square test of independence to look for significance. The result is extremely unambiguous, with Chi^2 = 92.90 and p = 0.000, proving that the probability of seeing these relationships between Class and Survival being essentially zero. This EDA strongly supports the conclusion that passenger class was a significant and meaningful predictor of survival on the Titanic. However, class may not be an isolated factor, as ticket prices may have varied between where they were purchased.

# %% [markdown]
# #### Adrianne - Class,  Fare and Embarked

# %% [markdown]
# Something that caught our attention while we were going over the project were the three columns -> Class, Fare and Embarked

# %%
## seaborn for plotting
import seaborn as sns
sns.set(font_scale=1.2, style="white")

# import matplotlib for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# set plotting size parameter
plt.rcParams['figure.figsize'] = (12, 5)

# import ANOVA
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd as tukeyhsd
from scipy.stats import f_oneway as anova

# improve resolution
# %config InlineBackend.figure_format ='retina'

# import cleaned dataset
df = pd.read_csv('data/02-processed/titanic_clean.csv')

# %% [markdown]
# The economic state of the world in 1912 was vastly different than the one we have in 2026. One such difference is the information gap between different countries, cities or even ports.
#
# As such, we were curious how the makeup of 'class' was for each 'embarked' town, and if a combination of one or the two affected the 'fare' their ports payed.
#
# Specifically, we want to know if different embarking locations were charged roughly the same.
#
# Let's define some null and alternates
#
# Our null in this scenario is that embarking location didn't have an effect on class or fare
#
# Our alternate is that some town or towns has a statistically significant difference in class or fare
#
# This would mean some sort of collinearity exists with embarked, class and fare, with one or both perhaps being a proxy for one of the three variables, which could worsen our model performance.
#
# Of the three embarking towns, of great note is the town Cherbourg, based in France and a well off city.

# %%
# View spread of embarking locations as well as number of entries, dropping entries  
df = df.dropna(how = "any", axis = 0, subset = ['fare', 'embarked', 'class'])
print(f'the current remaining entries are ' + str(df.shape[0])+'\n')

embarked_proportion = df['embarked'].value_counts()
print(embarked_proportion)
# Out:
# the current remaining entries are 712
#
# embarked
# S    554
# C    130
# Q     28
# Name: count, dtype: int64

# %% [markdown]
# For context,
#
# S = Southampton, England
#
# C = Cherbourg, France
#
# Q = Queenstown, New Zealand
#
#
# Let's view the distribution of fare between the three towns just as a baseline, without using the class of the ticket.

# %%
embarked_fare_plot = sns.violinplot(data = df, hue = 'embarked', y = 'fare')
embarked_fare_plot.set(xlabel='Embarking Location', ylabel='Fare (USD)')
embarked_fare_plot.legend(title = 'Embarking Location')

# %% [markdown]
# Interestingly, a good amount of positive fare outliers seem to sit in Cherbourg, let's verify

# %%
# Remember that Fare cutoff is the number calculated after

df_s = df[(df['embarked'] == 'S') & (df['fare'] > fare_cutoff)].shape[0]
df_c = df[(df['embarked'] == 'C') & (df['fare'] > fare_cutoff)].shape[0]
df_q = df[(df['embarked'] == 'Q') & (df['fare'] > fare_cutoff)].shape[0]
print(f'Southampton, England has {str(int(df_s))} positive outliers\nCherbourg, France has {str(int(df_c))} positive outliers\nQueenstown, New Zealand has {str(int(df_q))} positive outliers')
# Out:
# Southampton, England has 7 positive outliers
# Cherbourg, France has 11 positive outliers
# Queenstown, New Zealand has 0 positive outliers

# %% [markdown]
# Most outliers are in Cherbourg, which is consistent with academic papers describing France's economic status at the time
# https://www.cambridge.org/core/journals/journal-of-economic-history/article/belleepoque-of-portfolios-how-returns-risk-and-diversification-correlated-with-the-wealth-distribution-in-paris-in-1912/307C99BEC6B6B1566B7DFA009647D295
#
# Time to investigate Class between each town

# %%
df_s_passengers = df[(df['embarked'] == 'S')]['class'].value_counts()
df_c_passengers = df[(df['embarked'] == 'C')]['class'].value_counts()
df_q_passengers = df[(df['embarked'] == 'Q')]['class'].value_counts()

# %%
print(df_s_passengers)
print(f"the proportion of first class that Southampton took on was "+str(df_s_passengers['First']/embarked_proportion['S']))
# Out:
# class
# Third     290
# Second    156
# First     108
# Name: count, dtype: int64
# the proportion of first class that Southampton took on was 0.19494584837545126

# %%
print(df_c_passengers)
print(f"the proportion of first class that Cherbourg took on was "+str(df_c_passengers['First']/embarked_proportion['C']))
# Out:
# class
# First     74
# Third     41
# Second    15
# Name: count, dtype: int64
# the proportion of first class that Cherbourg took on was 0.5692307692307692

# %%
print(df_q_passengers)
print(f"the proportion of first class that Queenstown took on was "+str(df_q_passengers['First']/embarked_proportion['Q']))
# Out:
# class
# Third     24
# First      2
# Second     2
# Name: count, dtype: int64
# the proportion of first class that Queenstown took on was 0.07142857142857142

# %% [markdown]
# Here we can clearly and visually see that Cherbourg took on a significantly high proportion of First Class passengers compared to the other two. But did they pay more?

# %%
fare_c = df[df['embarked'] == "C"]["fare"].dropna()
fare_s = df[df['embarked'] == "S"]["fare"].dropna()
fare_q = df[df['embarked'] == "Q"]["fare"].dropna()

anova_results = anova(fare_c, fare_s, fare_q)
print(f'Analysis of Variance returns {anova_results[0]} difference with an associated p-value of {anova_results[1]}')
# Out:
# Analysis of Variance returns 35.892190453113834 difference with an associated p-value of 1.4184349041133077e-15

# %% [markdown]
# Clearly, the embarked category has a high effect on fare, we know that it's because Cherbourg's passengers were primarily First Class ticket holders, but let's statistically verify this result using a pairwise tukeyhsd

# %%
df_tukey = df.dropna(subset = ['fare', 'embarked'], how = 'any')
tukey = tukeyhsd(df_tukey['fare'], df_tukey['embarked'])
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#      C      Q  -50.031    0.0 -74.7503 -25.3117   True
#      C      S -40.8205    0.0 -52.3832 -29.2578   True
#      Q      S   9.2105 0.6143 -13.7714  32.1924  False
# ------------------------------------------------------

# %% [markdown]
# The mean difference from Cherbourg is -50 for Queenstown and -40 for Southampton, with statistically significant p values.
#
# We can then safely conlude that Cherbourg paid significantly higher overall, on high account of the town having a higher amount of first class passengers.
#
# This means that removing embarked could prove effective in dimensional reduction
#
# As a final useful tool, let's visualize our categories more cleanly.
#
# Note: We removed one outlier from Cherbourg to make the dataframe more readable

# %%
df_remove_one_outlier = df[df['fare'] < 350]
embarked_plot = sns.boxplot(data = df_remove_one_outlier, x = 'class', y = 'fare', hue = 'embarked', order = ['First', 'Second', 'Third'][::-1])

# %% [markdown]
# #### Section 2 of EDA - Prodding and Testing of Models
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %% [markdown]
# #### Connor - Logistic Regression of all Features
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
from sklearn.discriminant_analysis import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = df[main_features]
y = df['survived']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)

lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred  = lr.predict(X_test)
y_proba = lr.predict_proba(X_test)[:, 1]

# %% [markdown]
# The logistic regression model is evaluated using accuracy, ROC-AUC, and a confusion matrix. Feature coefficients (standardized) reveal which passenger characteristics drove the model's predictions. We also visualize survival rates across key demographic groups to corroborate the model's findings.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix, roc_curve

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_proba)
print(f"Accuracy : {acc:.3f}")
print(f"ROC-AUC  : {auc:.3f}")
print(classification_report(y_test, y_pred, target_names=['Did Not Survive', 'Survived']))

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Logistic Regression - Model Evaluation', fontsize=14, fontweight='bold')

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=['Did Not Survive', 'Survived'],
            yticklabels=['Did Not Survive', 'Survived'])
axes[0].set(title='Confusion Matrix', xlabel='Predicted', ylabel='True')

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_proba)
axes[1].plot(fpr, tpr, lw=2, color='steelblue', label=f'AUC = {auc:.3f}')
axes[1].plot([0, 1], [0, 1], 'k--', lw=1)
axes[1].set(title='ROC Curve', xlabel='False Positive Rate', ylabel='True Positive Rate')
axes[1].legend()

# Feature coefficients — hue='feature' fixes the palette deprecation warning
feature_labels = ['Passenger Class', 'Sex (Female=1)', 'Age', 'Log Fare', 'Family Size', 'Alone', 'Embarked']
coef_df = pd.DataFrame({'feature': feature_labels, 'coef': lr.coef_[0]}).sort_values('coef')
sns.barplot(data=coef_df, y='feature', x='coef', hue='feature', ax=axes[2], palette='coolwarm_r', legend=False)
axes[2].axvline(0, color='black', lw=0.8, ls='--')
axes[2].set(title='Feature Coefficients (standardized)', xlabel='Coefficient', ylabel='')

plt.tight_layout()
plt.show()
# Out:
# Accuracy : 0.804
# ROC-AUC  : 0.845
#                  precision    recall  f1-score   support
#
# Did Not Survive       0.84      0.84      0.84        85
#        Survived       0.76      0.76      0.76        58
#
#        accuracy                           0.80       143
#       macro avg       0.80      0.80      0.80       143
#    weighted avg       0.80      0.80      0.80       143

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Survival Rates by Passenger Characteristics', fontsize=14, fontweight='bold')

sns.barplot(data=df, x='sex', y='survived', hue='sex', palette='Set2', legend=False, ax=axes[0])
axes[0].set(title='Survival Rate by Sex', xlabel='Sex', ylabel='Survival Rate')

sns.barplot(data=df, x='pclass', y='survived', hue='pclass', palette='RdYlGn_r', legend=False, ax=axes[1])
axes[1].set(title='Survival Rate by Passenger Class', xlabel='Passenger Class', ylabel='Survival Rate')

sns.histplot(data=df, x='age', hue='survived', bins=25, kde=True, palette='Set1', ax=axes[2])
axes[2].set(title='Age Distribution by Survival', xlabel='Age', ylabel='Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# Crew members are not accounted for in the dataset, so their survival rates will not be accounted for or modeled accurately. Additionally, our analysis of the tragedy will be restricted to numeric and categorical data, which will not take into account any emotional and psychological factors in play.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# It is well-known that a "women and children first" policy was implemented in evacuating the Titanic, causing an irreversible categorical change that will affect survival rates. We are aware of this effect and are actively going to be monitoring its effects, and will reserve any conclusions we make on survival rates with the skew in mind.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# The correlations that we are exploring are more the result of contemporary discriminatory or otherwise biased views i.e. valuing women and children more, rather than the characteristics of the passengers themselves which we are measuring. The included visualizations are based on measurable and/or clearly identifiable passenger characteristics to generalize and identify larger trends. We will also reserve conclusions to within reason, i.e. any conclusion that "women and children were more likely to survive" will be carefully ftamed with its context (WCS policy called, not enough lifeboats) and the acknowledgement that both regulation and policy on cruise ships have changed since 1912.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# We have ensured that this dataset does not include passenger names or otherwise unnecessary PII.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# While we are using proxy variables (Ticket Class and Fare to proxy for wealth/social status), we are aware and are actively categorizing them to test the biases that these variables introduce into models. We will also keep in mind that this bias should be taken into account and checked for most if not all EDA we perform.
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# We will be subsetting our own data, and if time permits, use a unique enough and compatible enough dataset to confirm performance monitoring.
#
# We will also be disclaiming that the conclusions from this data, and by extension, the Titanic, have already been used for many policy changes, engineering design changes, and also that the Titanic is considered an engineering marvel, meaning its protocol and structure are uniquely different from its own ships from its time, let alone ships today. Because of this, we will comfortably restrict our conclusions to apply most likely to other Olympic Class vessels and Cruise ships sailing on or around the year 1914.
#
# The use of model accuracy maintenance
#
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# While the models themselves should be relatively flexible enough to be useful for other datasets, we will carefully monitor the conclusions made using our findings, so as to acknowledge the uniqueness and datedness of the Titanic's situation.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 01/27 |No Meeting|N/A|Contact Project Groupmates, Discuss General and Meeting Expectations, Form Group Chat|
# | 2/04  |3PM|Individual research, Suggest & finalize topic, Some 0-Proposal work|Finish 0-Proposal, Merge changes. Quick Overview of 1-Data work|
# | 2/04  |MIDNIGHT|00-Proposal Deadline|N/A|
# | 2/10  |ASYNC|Check in on 1-Data work|Assign 1-Data work , Discuss project direction|
# | 2/18  |3PM|Individual work on 1-Data|Finish individual 1-Data work, Merge changes, Quick overview of 2-EDA work|
# | 2/18  |MIDNIGHT|01-Data Deadline|N/A|
# | 2/24  |3PM|Individually go over 2-EDA work | Assign 1-Data work, Check in on project changes, Assign Point Retrieval|
# | 3/03  |3PM|Finish assigned 2-EDA work & Point Retrieval | Discuss findings, Merge 2-EDA Changes, Quick Overview of 03-Final, Point backs and Video|
# | 3/04  |MIDNIGHT|02-EDA Deadline |N/A|
# | 3/10  |3PM|Check in on 3-Final progress|Check in on work, Reaassign as needed, Finishing touches|
# | 3/17  |ASYNC|Finalize 3-Final Work|Individual Merges to main, Check on work, Confirm all requirements are done, Finish Post-Course & Team Surveys|
# | 3/18  |MIDNIGHT|03-Final Deadline|N/A|
