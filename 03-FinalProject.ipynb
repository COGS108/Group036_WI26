# %% [markdown]
# # COGS 108 - Causal Analysis and Model Prediction on Unique Titanic Dataset
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# In this project, we investigated whether passenger characteristics on the Titanic affected survival and whether these factors could be used to predict survivability. We focused on variables such as gender, age, and passenger class, especially in the context of the “Women and Children First” policy. We also wanted to determine if survival outcomes were mostly explained by these characteristics or if there was still a large element of randomness.
#
# To do this, we used and cleaned a dataset 891 passengers, removing missing values and preparing the data for analysis. We performed EDA and statistical tests, including chi-squared tests and t-tests, to examine relationships between variables and survival. We then built several machine learning models, including logistic regression and a support vector machine (SVM), using features like class, age, fare, and family size, and evaluated their performance using accuracy and ROC-AUC.
#
# We found that gender and passenger class were the strongest predictors of survival. Female passengers and higher classes were significantly more likely to survive, supporting the impact of social norms and access to resources. Age had a smaller effect, with younger passengers slightly more likely to survive. Our models achieved moderate accuracy (around 78–83%), showing that survival was not random but also not perfectly predictable, suggesting that both structured factors and chance played a role.

# %% [markdown]
# ## Authors
#
# - Adrianne Steven See: Analysis, Conceptualization, Data Curation, Experimental Investigation, Methodology, Software, Visualization, Writing - original draft, Writing - review & editing
# - Harvey Sandhu: Background Research, Conceptualization, Experimental Investigation, Visualization, Writing - original draft
# - Kyle Wu: Analysis, Background Research, Conceptualization, Experimental Investigation, Methodology, Visualization, Writing - original draft, Writing - review and editing
# - Connor Wu: Conceptualization, Data Curation, Methodology, Project Administration, Software, Visualization, Writing - original draft, Writing = review & editing
# - Teddy Nguyen: Background Research - Conceptualization, Experimental Investigation, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# Did the characteristics of passengers on the Titanic (class, age, ticket, gender) affect their survivability?
#
# - Considering the use of the "Women and Children First" rule during its evacuation, how effective was it in increasing the survival rate of its corresponding demographic?
#
# - Did passengers who "splurged" or were able to afford a higher class ticket, have an increased survival rate?
#
# - Can we create and tune a model to predict a passenger's survivability for the Titanic? or was "Disaster Randomness" significant in our dataset?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The RMS Titanic needs little introduction. A massive Olympic class ocean liner stretching 882ft long and 175 feet high, its size is only overshadowed by its reputation of sinking on its maiden voyage. On April 15, 1912, near midnight, a starboard collision with an iceberg damaged and flooded too many internal compartments, and the Titanic started sinking. Despite having a capacity of around 3300 passengers, the amount of lifeboats on board were only enough for about 1100 passengers, and a "Women and Children First" protocol was established and generally carried out. Of the roughly 2200 on board the Titanic, only around 700 actually survived.
#
# The dataset we are analyzing includes information on 891 passengers, including their passenger class, age, sex, and their accompaniment. Catastrophic events are usually considered indiscriminate, but research consistently shows that certain factors shape survival outcomes. These include categories and numericals such as socioeconomic status (SES), age, and gender.
#
# ### Similar studies:
#
# A paper from Bowdoin College found that the Titanic, like many disasters, had "differential effects" in which survival and suffering were unequally distributed across class, age, and gender lines. Researchers found that first-class passengers had a survival rate of about 62%, compared to 41% in second class and only 25% in third class (Bowdoin), showcasing stark socioeconomic differences translated to better survival rates. They theorize that this was due to the higher status translating into better access to information, lifeboats, and life-saving opportunities. The paper also incorporates a diagram of the Titanic, showcasing that third class passengers were housed lower, second class in the lower middle, and first class in the upper middle sections of the boat. This diagram led them to believe that if the boat were sinking, the first-class passengers had more time to reach life-saving measures. The same image showcases that women and children had much higher rates of survival, with 75 and 50 percent, respectively, while men only had about 20% survival. This follows suit with the order Captain E.J. Smith gave to officers, "Women and Children First." The paper also mentions that certain officers interpreted these orders differently, with Officer Lightroller taking the order to mean women and children only, lowering lifeboats even before full capacity to prioritize women and children's survival.
#
# In another analysis, Frey, Heggli, and Osterloh used individual-level Titanic data to test how economic resources, age, and gender affected the probability of survival. Aside from reconfirming that class and gender played a large role in the probability of survival, they showed age mattered as well. People in their "prime" (ages around 15-35) were more likely to survive than older passengers (Frey et al.), suggesting that physical mobility and stamina interacted with the other categories to shape outcomes.
#
# A study similar to our proposed topic, but with a slightly different data set, concluded that gender was, in fact, the key determining factor in survivability.
#
# Because this is a historical topic, we can safely assume that there will be no issues with outdated data or analysis, but the data sets being analyzed may have varying results. Despite being the same size, with 891 passengers, the data set we are analyzing has some additional information that may reveal more nuance in the death statistics. Additionally, the individuals may be different, meaning a different population of the Titanic survivors was sampled.
#
# An article from the NIH states that, despite the widespread belief of prioritizing women and children in maritime accidents, women in fact have a significant survival disadvantage in these situations It further asserts that despite the survival rate of women on the Titanic being significantly higher, in the grander scheme of maritime accidents, data actually implies the opposite.
#
# ### Citations:
#
# "Analysis of Titanic Survival Data", ttsteiger.github.io/projects/titanic_report.html. Accessed 4 Feb. 2026.
#
# Elinder, Mikael, and Oscar Erixson. "Gender, Social Norms, and Survival in Maritime Disasters." Proceedings of the National Academy of Sciences of the United States of America, U.S. National Library of Medicine, 14 Aug. 2012, pmc.ncbi.nlm.nih.gov/articles/PMC3421183/.
#
# Bowdoin. "Disproportionate Devastation | Titanic." Bowdoin, 2020, courses.bowdoin.edu/history-2203-fall-2020-kmoyniha/reflection/.
#
# Frey, Bruno S, et al. "Surviving the Titanic Disaster: Economic, Natural and Social Determinants." Escholarship.org, Feb. 2009, escholarship.org/uc/item/6h24b1vt.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that a decent amount of characteristics had a significant effect on surviving the Titanic, and consequently, modeling Titanic survival rates will be both effective and significant.
#
# We believe that
# - The gender data point will be the most correlated. The use of “Women and Children first” or the WCF order, during the Titanic’s sinking had a major positive impact on the survival rates of Females and Passengers that would fit the “Children” characteristic.
#
# - The next data point will have some sort of proxy for social class. We primarily believe that the ticket class will do this most effectively. This, we think, will be due to a number of factors, primarily a prevailing classism present during the time period, as well as a number of physical characteristics such as the location of second and third class passengers being lower on the Titanic compared to first class passengers.
#
# - Finally, we believe that an accurate prediction model will use more than these data points. That is, for a hyperparameter tuned model, we will employ more than the class and gender.

# %% [markdown]
# ## Data Analysis Setup
# To avoid unnecessary back and forth, see the code below for the relevant import statements and plotting settings.

# %%
## import critical modules
import os

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
plt.rcParams['figure.figsize'] = (12, 6)

import seaborn as sns
sns.set(font_scale=1.2, style="white")

import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd as tukeyhsd

from scipy import stats
from scipy.stats import f_oneway as anova
from sklearn.discriminant_analysis import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, precision_recall_fscore_support, roc_auc_score, accuracy_score, confusion_matrix, roc_curve

# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# We used the "Titanic Dataset" from github user shraddha4ever20.
#
# We found that this dataset is well-suited for our research question since it includes individual-level information on survival, age, sex, ticket class, and fare for 891 passengers. We also found that this dataset has an interesting inclusion,'alone' which we will explore later on. These records are retrieved from embarkation manuscripts as well as other documents as pieced together from the National Archives.
#
# In an ideal scenario, we would work with a complete manifest that includes all passengers and crew, precise cabin locations, lifeboat assignments, and verified socioeconomic status indicators directly sourced from the original passenger documents. That dataset would eliminate sampling bias and enabld more detailed modeling of how physical location on the ship and social status affected the changes of reaching a lifeboat
#
# Despite this, although the dataset represents a sample rather than the full passenger and crew list, it is large enough to support meaningful statistical analysis for our project. Each row in the kaggle dataset corresponds to a single passenger and includes variables such as survival status (0 = did not survive, 1 = survived), passenger class (which we will analyze as a socioeconomic status proxy), sex, age, fare (ticket price), and a few additional identifiers which we want to investigate later on to check for possible meaningful causal inference indications.
#
# While we want to preserve as many data points and entries, it does containa null values for passenger ages, which indicate a need to clean the dataset further. It also contains some repeated data in different formats (e.g., passenger class in both numeric and string formats). While this is not inherently a downside, it forces us to decide which format works better for our analysis and modeling purpoes.
#
# The dataset was retrieved in CSV format, and can be found here: https://www.kaggle.com/datasets/shraddha4ever20/titanic-datset

# %% [markdown]
# ### Titanic Dataset
#
# #### From the Kaggle website:
# ```pclass – Passenger class (1st, 2nd, 3rd)```
#
# ```sex – Gender of passenger```
#
# ```age – Age in years```
#
# ```sibsp – Number of siblings/spouses aboard```
#
# ```parch – Number of parents/children aboard```
#
# ```fare – Ticket fare in dollars```
#
# ```who – Man, woman, or child```
#
# ```adult_male – Boolean indicator for adult male```
#
# ```deck – Deck level (where available) (A, B, C, D, E, null)```
#
# ```embark_town – Town of embarkation in string format (Cherbourg, Queenstown, or Southampton)```
#
# ```alive – Survival status (Yes/No)```
#
# ```alone – Boolean indicator if passenger was alone```
#
#
# The dataset is not composed of the entire Titanic manifest, as it only has 891 of the 2208 passengers. This is not proof of a biased dataset, but it is not fully representative and/or entirely historically accurate in terms of names (which this dataset has omitted for privacy reasons)

# %%
df = pd.read_csv('data/00-raw/titanic.csv')
print(f"Shape:, {df.shape}\n")
print(f"Data types:\n {df.dtypes}\n")

missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)
print("Missing values:\n", pd.DataFrame({'count': missing, 'pct': missing_pct})[missing > 0],"\n")

# drop rows where Age is missing
df = df.dropna(subset='age')

# drop deck entirely
df = df.drop('deck', axis = 1)

# drop the two data points corresponding to missing embarkations
df = df.dropna(subset=['embarked','embark_town'])

# Flag fare outliers
fare_cutoff = df['fare'].mean() + 3 * df['fare'].std()
print(f"Fare outliers (>{fare_cutoff:.2f}): {len(df[df['fare'] > fare_cutoff])} rows\n")

print("Summary stats:\n", df[['survived', 'pclass', 'age', 'fare']].describe().round(2),"\n")
print("Final shape:", df.shape)

os.makedirs('data/02-processed', exist_ok=True)
df.to_csv('data/02-processed/titanic_clean.csv', index=False)
print("Saved to data/02-processed/titanic_clean.csv")

# Clear df to ensure future EDA doesn't mistakenly use it
df = None
# Out:
# Shape:, (891, 15)
#
# Data types:
#  survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object
#
# Missing values:
#               count    pct
# age            177  19.87
# embarked         2   0.22
# deck           688  77.22
# embark_town      2   0.22
#
# Fare outliers (>193.38): 18 rows
#
# Summary stats:
#         survived  pclass     age    fare
# count    712.00  712.00  712.00  712.00
# mean       0.40    2.24   29.64   34.57
# std        0.49    0.84   14.49   52.94
# min        0.00    1.00    0.42    0.00
# 25%        0.00    1.00   20.00    8.05
# 50%        0.00    2.00   28.00   15.65
# 75%        1.00    3.00   38.00   33.00
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %%
titanic = pd.read_csv('data/02-processed/titanic_clean.csv')

# %% [markdown]
# ## Analyzing Columnwise Correlation, Dimensionality, and Summary Statistics
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %% [markdown]
# ### Question 1: "Was the Women and Children First" Order Effective?"
# Note: The deck column is missing for 96% of passengers and won't be useful for this analysis. Additionally, decks were shared between the classes, so we will be omitting deck level from this analysis completely.
#
# First, let's analyze our target variable, 'alive'.
#
# A main factor consistent with multiple other research reports was the use and effectiveness of the "Women and Children First" order given by Captain E.J. Smith. Given this in mind, let's see how much our dataset reflects this conclusion.

# %%
nonsurvivors, survivors = [x for _, x  in titanic.groupby(titanic['survived'] == 1)]

female_survivors, male_survivors = [x for _, x  in survivors.groupby(titanic['sex'] == 'male')]
female_nonsurvivors, male_nonsurvivors = [x for _, x  in nonsurvivors.groupby(titanic['sex'] == 'male')]

print("")
print("Total Passengers (With Valid Age): ", titanic.shape[0], "\n")
print("Male Passengers: ", male_survivors.shape[0] + male_nonsurvivors.shape[0])
print("Female Passengers: ", female_survivors.shape[0] + female_nonsurvivors.shape[0], '\n')
print("Male Survivors: ", male_survivors.shape[0])
print("Female Survivors: ", female_survivors.shape[0], '\n')
print("Male Nonsurvivors: ", male_nonsurvivors.shape[0])
print("Female Nonsurvivors: ", female_nonsurvivors.shape[0], "\n")

print("Average Male Survivors Age: ", male_survivors['age'].mean().round(2))
print("Average Female Survivors Age: ", female_survivors['age'].mean().round(2))
print("Average Male Nonsurvivors Age: ", male_nonsurvivors['age'].mean().round(2))
print("Average Female Nonsurvivors Age: ", female_nonsurvivors['age'].mean().round(2), "\n")

print("Survivor Stats:\n", survivors[["age"]].describe().round(2), "\n")
print("Nonsurvivor Stats:\n", nonsurvivors[["age"]].describe().round(2),"\n")
# Out:
# Total Passengers (With Valid Age):  712
#
# Male Passengers:  453
# Female Passengers:  259
#
# Male Survivors:  93
# Female Survivors:  195
#
# Male Nonsurvivors:  360
# Female Nonsurvivors:  64
#
# Average Male Survivors Age:  27.28
# Average Female Survivors Age:  28.63
# Average Male Nonsurvivors Age:  31.62
# Average Female Nonsurvivors Age:  25.05
#
# Survivor Stats:
#            age
# count  288.00
# mean    28.19
# std     14.86
# min      0.42
# 25%     19.00
# 50%     28.00
# 75%     36.00
# max     80.00
#
# Nonsurvivor Stats:
#            age
# count  424.00
# mean    30.63
# std     14.17
# min      1.00
# 25%     21.00
# 50%     28.00
# 75%     39.00
# max     74.00

# %% [markdown]
# Let's visualize this information first, to better inspect it.

# %%
survivor_palette = ["#228b22","#b22222"]

survivor_plot = sns.histplot(
    data = titanic,
    x = 'alive',
    hue = 'alive',
    hue_order = ['yes', 'no'],
    palette = survivor_palette,
    stat = 'probability',
    multiple = 'dodge',
    shrink = 0.8)
plt.xlabel("Alive?")
plt.ylabel("Proportion")
plt.ylim(0,1)
plt.title("Survival Data")

plt.show()

# %%
survivor_plot_gendered = sns.histplot(
    data=titanic, 
    x = "sex", 
    hue = 'alive', 
    common_norm = False, 
    multiple = 'dodge', 
    stat = 'probability', 
    hue_order = ['no', 'yes'], 
    palette = survivor_palette[::-1], 
    shrink = 0.8)
plt.title("Male vs Female Survival Data")
plt.ylabel("Proportion")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# Comparing the graphs, as well as verifying with the numerical statistics from earlier, we can clearly see that there was a significant correlation between female passengers and surviving the titanic that goes against the aggregate pattern. We will verify this conclusion with a Chi-Squared test to retrieve its p-value

# %%
chi_squared_sex = stats.chi2_contingency(
    [[male_survivors.shape[0], male_nonsurvivors.shape[0]], 
     [female_survivors.shape[0], female_nonsurvivors.shape[0]]]
)
print("\nChi-Squared Test on 'sex' Categorical:")
print("Statistic: ", chi_squared_sex.statistic)
print("P-Value: ", chi_squared_sex.pvalue, '\n')
# Out:
# Chi-Squared Test on 'sex' Categorical:
# Statistic:  202.86944877617123
# P-Value:  4.939416685451492e-46

# %% [markdown]
# The significantly lower p-value tells us to reject the null hypothesis of zero correlation. Further, the statistical effects i This is to say, there is a statistically significant correlation between gender and survival rates.
#
# Moving on to Age, let's perform the same demographic tests, this time to confirm the "Children" portion of "Women and Children First"

# %%
age_plot = sns.histplot(
    data = titanic,
    x = 'age',
    multiple = 'dodge',
    legend = False
)
plt.ylim(0,100)
plt.title("Passenger Composition of the Titanic by Age")
plt.xlabel('Age')
plt.show()

# %%
age_survivor_plot = sns.histplot(
    data = titanic[titanic['survived'] == 1],
    x = 'age',
    hue = 'survived',
    palette = [survivor_palette[0]],
    multiple = 'dodge',
    legend = False
)
plt.ylim(0,100)
plt.title("Titanic Survivor Compositon by Age")
plt.xlabel('Age')
plt.show()

# %% [markdown]
# Visual representation is unclear. It's hard to tell, so let's perform a t-test.

# %%
ttest_age = stats.ttest_ind(survivors["age"], nonsurvivors["age"])
print("T-Test for Age:")
print("Statistic: ", ttest_age.statistic)
print("P-Value: ", ttest_age.pvalue)
# Out:
# T-Test for Age:
# Statistic:  -2.2043427748445956
# P-Value:  0.027820316250851285

# %% [markdown]
# The P-Value tells us that survivors were, on average, younger. Finally, let's add a new categorical to our dataset named 'is_child' to better capture the effect, since the rule was "Children first", not "Younger first".

# %%
titanic['is_child'] = titanic['age'] < 18

child_survivors = titanic[(titanic['is_child']) & (titanic['survived'] == 1)]
child_nonsurvivors = titanic[(titanic['is_child']) & (titanic['survived'] == 0)]
adult_survivors = titanic[(~titanic['is_child']) & (titanic['survived'] == 1)]
adult_nonsurvivors = titanic[(~titanic['is_child']) & (titanic['survived'] == 0)]

chi_squared_age = stats.chi2_contingency(
    [[child_survivors.shape[0], child_nonsurvivors.shape[0]],
     [adult_survivors.shape[0], adult_nonsurvivors.shape[0]]]
)

print("\nChi-Squared Test on 'child' Categorical:")
print("Statistic: ", chi_squared_age[0])
print("P-Value: ", chi_squared_age[1], '\n')
# Out:
# Chi-Squared Test on 'child' Categorical:
# Statistic:  9.555162653822242
# P-Value:  0.0019938784449183987

# %% [markdown]
# Finally, we can safely conclude that both Women and Children did benefit from the employment of the "Women and Children First" order.

# %% [markdown]
# ### Question 2: Were Higher (Socioeconomic) Class More Likely To Survive?

# %% [markdown]
# Socioeconomic Class is a hard to capture variable in this situation. For this area of the EDA, we will make the assumption that passenger class translates roughly to Socioeconomic Class, due to the higher fare rate associated with class (we will go over this in more detail later). Here, we will just concern ourselves with passenger class ```[1,2,3]``` and it's effect on survivorship.

# %%
print(titanic['pclass'].value_counts().sort_index())
print(f"\nProportion of Titanic Dataset that Survived: {titanic['survived'].value_counts().loc[0]/titanic.shape[0]}")
# Out:
# pclass
# 1    184
# 2    173
# 3    355
# Name: count, dtype: int64
#
# Proportion of Titanic Dataset that Survived: 0.5955056179775281

# %% [markdown]
# The class breakdown is notably uneven: Third Class passengers account for 49.7% of all passengers (355 of 712), nearly as many as First and Second combined. This is important context, as any aggregate count will be naturally dominated by Third Class, so we should work in rates rather than raw counts.

# %%
survival_by_class = titanic.groupby('pclass')['survived'].agg(['mean', 'sum', 'count'])
survival_by_class.columns = ['survival_rate', 'survivors', 'total']
survival_by_class['survival_rate'] = survival_by_class['survival_rate'].round(3)
print(survival_by_class)

survival_by_class['survival_rate'].plot(kind='bar', color=['gold', 'silver', '#cd7f32'])
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.show()
# Out:
#         survival_rate  survivors  total
# pclass
# 1               0.652        120    184
# 2               0.480         83    173
# 3               0.239         85    355

# %% [markdown]
# We can immediately see that First class has both a higher survival rate and around 40 more total survivors than Second and Third class each, while having close to the same number of passengers as Second class and roughly half as many passengers as Third class.
#
# First Class passengers survived at a rate of 65.2%, which is roughly 2.5 times higher than Third Class passengers at 23.9%.
#
# Also note that the difference from first to second class is roughly linear, as well as the difference from second to third class. This implies a linear relationship between the pclass and survival rates, which we can leverage for our model. This is because this now allows us to avoid needing to encode these variables, seeing as how the relationship is, again, linear.

# %% [markdown]
# ##### Crosstab Heatmap of Survival Data
#
# Next, we'll use a heatmap to see how the ratio of survival was affected in each class.

# %%
ct = pd.crosstab(titanic['pclass'], titanic['survived'], normalize='index')
sns.heatmap(ct, annot=True, fmt='.2%', cmap='RdYlGn')
plt.title('Survival Rate by Class (% of each class)')
plt.show()

# %% [markdown]
# Second class stands out as the most even split, with roughly half surviving and half not. First and Third class have inverted patterns, with Third class being the most dramatic split.

# %% [markdown]
# ##### Is the Correlation Statistically Significant?

# %%
ct_raw = pd.crosstab(titanic['pclass'], titanic['survived'])
chi2, p, dof, expected = stats.chi2_contingency(ct_raw)

n = ct_raw.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct_raw.shape) - 1)))

print(f"Chi2:      {chi2:.2f}")
print(f"P-value:   {p:.20f}")
# Out:
# Chi2:      91.08
# P-value:   0.00000000000000000002

# %% [markdown]
# Because both pclass and survived are categorical variables, we'll use the Chi-Square test of independence to look for significance. The result is extremely unambiguous, with Chi^2 = 92.90 and p = 0.000, proving that the probability of seeing these relationships between Class and Survival being essentially zero. This EDA strongly supports the conclusion that passenger class was a significant and meaningful predictor of survival on the Titanic. However, class may not be an isolated factor, as ticket prices may have varied between where they were purchased.

# %% [markdown]
# ### Area of Concern - Possible Multicollinearity between Class, Fare and Embarked

# %% [markdown]
# Something that caught our attention while going over the dataset were three columns -> ```Class```, ```Fare``` and ```Embarked```

# %% [markdown]
# The economic state of the world in 1912 was vastly different than the one we have in 2026. One such difference is the information gap between different countries, cities or even ports.
#
# As such, we were curious how the makeup of 'class' was for each 'embarked' town, and if a combination of one or the two affected the 'fare' their ports payed.
#
# Specifically, we want to know if different embarking locations were charged roughly the same.
#
# Let's define some null and alternates
#
# Our null in this scenario is that embarking location didn't have an effect on class or fare
#
# Our alternate is that some town or towns has a statistically significant difference in class or fare
#
# This would mean some sort of collinearity exists with embarked, class and fare, with one or both perhaps being a proxy for one of the three variables, which could worsen our model performance.
#
# Of the three embarking towns, of great note is the town Cherbourg, based in France.

# %%
# View spread of embarking locations as well as number of entries, dropping entries  
embarked_proportion = titanic['embarked'].value_counts()
print('Counts of Passengers based on Embarking Location\n', embarked_proportion)
# Out:
# Counts of Passengers based on Embarking Location
#  embarked
# S    554
# C    130
# Q     28
# Name: count, dtype: int64

# %% [markdown]
# For context,
#
# S = Southampton, England
#
# C = Cherbourg, France
#
# Q = Queenstown, New Zealand
#
#
# Let's view the distribution of fare between the three towns just as a baseline, without using the class of the ticket.

# %%
embarked_fare_plot = sns.violinplot(data = titanic, hue = 'embarked', y = 'fare')
embarked_fare_plot.set(xlabel='Embarking Location', ylabel='Fare (USD)')
plt.legend(title = 'Embarking Location')
plt.show()

# %% [markdown]
# Interestingly, a good amount of positive fare outliers seem to sit in Cherbourg, let's verify

# %%
# Remember that Fare cutoff is the number calculated after

df_s = titanic[(titanic['embarked'] == 'S') & (titanic['fare'] > fare_cutoff)].shape[0]
df_c = titanic[(titanic['embarked'] == 'C') & (titanic['fare'] > fare_cutoff)].shape[0]
df_q = titanic[(titanic['embarked'] == 'Q') & (titanic['fare'] > fare_cutoff)].shape[0]
print(f'Southampton, England has {str(int(df_s))} positive outliers\nCherbourg, France has {str(int(df_c))} positive outliers\nQueenstown, New Zealand has {str(int(df_q))} positive outliers')
# Out:
# Southampton, England has 7 positive outliers
# Cherbourg, France has 11 positive outliers
# Queenstown, New Zealand has 0 positive outliers

# %% [markdown]
# Most outliers are in Cherbourg, which is consistent with academic papers describing France's economic status at the time
#
# Source: https://www.cambridge.org/core/journals/journal-of-economic-history/article/belleepoque-of-portfolios-how-returns-risk-and-diversification-correlated-with-the-wealth-distribution-in-paris-in-1912/307C99BEC6B6B1566B7DFA009647D295
#
# Time to investigate Class between each town

# %%
df_s_passengers = titanic[(titanic['embarked'] == 'S')]['class'].value_counts()
df_c_passengers = titanic[(titanic['embarked'] == 'C')]['class'].value_counts()
df_q_passengers = titanic[(titanic['embarked'] == 'Q')]['class'].value_counts()

# %%
print(df_s_passengers)
print(f"the proportion of first class that Southampton took on was "+str(df_s_passengers['First']/embarked_proportion['S']))
# Out:
# class
# Third     290
# Second    156
# First     108
# Name: count, dtype: int64
# the proportion of first class that Southampton took on was 0.19494584837545126

# %%
print(df_c_passengers)
print(f"the proportion of first class that Cherbourg took on was "+str(df_c_passengers['First']/embarked_proportion['C']))
# Out:
# class
# First     74
# Third     41
# Second    15
# Name: count, dtype: int64
# the proportion of first class that Cherbourg took on was 0.5692307692307692

# %%
print(df_q_passengers)
print(f"the proportion of first class that Queenstown took on was "+str(df_q_passengers['First']/embarked_proportion['Q']))
# Out:
# class
# Third     24
# First      2
# Second     2
# Name: count, dtype: int64
# the proportion of first class that Queenstown took on was 0.07142857142857142

# %% [markdown]
# Here we can clearly and visually see that Cherbourg took on a significantly high proportion of First Class passengers compared to the other two. But did they pay more?

# %%
fare_c = titanic[titanic['embarked'] == "C"]["fare"]
fare_s = titanic[titanic['embarked'] == "S"]["fare"]
fare_q = titanic[titanic['embarked'] == "Q"]["fare"]

anova_results = anova(fare_c, fare_s, fare_q)
print(f'Analysis of Variance returns {anova_results[0]} difference with an associated p-value of {anova_results[1]}')
# Out:
# Analysis of Variance returns 35.892190453113834 difference with an associated p-value of 1.4184349041133077e-15

# %% [markdown]
# Clearly, the embarked category has a high effect on fare, we know that it's because Cherbourg's passengers were primarily First Class ticket holders, but let's statistically verify this result using a pairwise tukeyhsd

# %%
tukey = tukeyhsd(titanic['fare'], titanic['embarked'])
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#      C      Q  -50.031    0.0 -74.7503 -25.3117   True
#      C      S -40.8205    0.0 -52.3832 -29.2578   True
#      Q      S   9.2105 0.6143 -13.7714  32.1924  False
# ------------------------------------------------------

# %% [markdown]
# The mean difference from Cherbourg is -50 for Queenstown and -40 for Southampton, with statistically significant p values.
#
# We can then safely conlude that Cherbourg paid significantly higher overall, on high account of the town having a higher amount of first class passengers.
#
# This means that removing embarked could prove effective in dimensional reduction
#
# As a final useful tool, let's visualize our categories more cleanly.
#
# Note: We already know that First Class has many outliers, so keeping that data is not significantly more useful in comparing central tendencies between the categories. The plot has been limited to fares up to 175 for easier comparison of central tendenceies.

# %%
df_remove_one_outlier = titanic[titanic['fare'] < 350]
embarked_plot = sns.boxplot(data = df_remove_one_outlier, 
                            x = 'class', 
                            y = 'fare', 
                            hue = 'embarked', 
                            order = ['First', 'Second', 'Third'][::-1])
plt.ylim(0,175)
plt.show()

# %% [markdown]
# ## Question 3 - How Accurate Can We Predict Survival Rates on The Titanic?

# %% [markdown]
# ### Feature Engineering
#
# Taking into account all our Exploratory Data Analysis has performed, let's start to deploy models and test their accuracy scores, rates of accuracy, and rates of true positive-false positive using ROC-AUC
#
# First, let's prep our dataset further for Machine Learning
#
# Let's engineer a feature that captures 'sibsp' (number of siblings and spouses) and 'parch' (number of parents and children).
# A variable named 'family_size' will do. Let's define it as a datapoint's ```sibs + parch + 1 (include themselves)```
#
# Let's also encode the embarking town. Recall that Southampton has the most entries in its category. This means it'll be a useful baseline for our encoding.
#
# Finally, let's encode 'is_male', as we noticed earlier that again, a large amount of our dataset is male.

# %%
titanic_ml = titanic.copy()

titanic_ml['family_size'] = titanic_ml['sibsp'] + titanic_ml['parch'] + 1
titanic_ml['is_male'] = titanic_ml['sex'].map({'male': 1, 'female': 0})
titanic_ml['embarked_c'] = (titanic_ml['embarked'] == 'C').astype(int)
titanic_ml['embarked_q'] = (titanic_ml['embarked'] == 'Q').astype(int)

# %% [markdown]
# This section will be a large amount of code blocks, so let's define a useful report to summarize our model performance.
#
# report_titanic will return the accuracy_score, ROC-AUC score, and the classification report of our models.
#
# Note that we will be using an 80/20 test train split for the rest of this portion, something easily verifiable

# %%
def report_titanic(features, model_type, y_train, y_pred_train, y_proba_train, y_test, y_pred_test, y_proba_test):
    print(f"Results on regression on 'titanic_ml' Dataset with {model_type}\n\n")
    print(f"Using features = {features}\n\n")
    
    print("Training dataset\n")
    print(f"Accuracy: {accuracy_score(y_train, y_pred_train):.3f}")
    print(f"ROC-AUC: {roc_auc_score(y_train, y_proba_train):.3f}")
    print(classification_report(y_train, y_pred_train))
    
    print("Testing dataset\n")
    print(f"Accuracy: {accuracy_score(y_test, y_pred_test):.3f}")
    print(f"ROC-AUC: {roc_auc_score(y_test, y_proba_test):.3f}")
    print(classification_report(y_test, y_pred_test))
    return

# %% [markdown]
# ### Logistical Regression, Blind

# %%
features_baseline = ['pclass', 'is_male', 'age', 'family_size', 'fare', 'embarked_c', 'embarked_q']
X_base = titanic_ml[features_baseline]
y_base = titanic_ml['survived']

X_train_base, X_test_base, y_train_base, y_test_base = train_test_split(
    X_base, y_base, test_size=0.2, random_state=42, stratify=y_base
)

scaler_base = StandardScaler()
X_train_base_scale = scaler_base.fit_transform(X_train_base)
X_test_base_scale = scaler_base.transform(X_test_base)

lr_base = LogisticRegression(max_iter=1000, random_state=42)
lr_base.fit(X_train_base_scale, y_train_base)

y_pred_train_base = lr_base.predict(X_train_base_scale)
y_pred_test_base = lr_base.predict(X_test_base_scale)
y_proba_train_base = lr_base.predict_proba(X_train_base_scale)[:,1]
y_proba_test_base = lr_base.predict_proba(X_test_base_scale)[:,1]

report_titanic(features_baseline,
               "Blind Logistic Regression", 
               y_train_base, 
               y_pred_train_base, 
               y_proba_train_base,
               y_test_base, 
               y_pred_test_base,
               y_proba_test_base)
# Out:
# Results on regression on 'titanic_ml' Dataset with Blind Logistic Regression
#
#
# Using features = ['pclass', 'is_male', 'age', 'family_size', 'fare', 'embarked_c', 'embarked_q']
#
#
# Training dataset
#
# Accuracy: 0.796
# ROC-AUC: 0.859
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       339
#            1       0.77      0.71      0.74       230
#
#     accuracy                           0.80       569
#    macro avg       0.79      0.78      0.79       569
# weighted avg       0.79      0.80      0.79       569
#
# Testing dataset
#
# Accuracy: 0.783
# ROC-AUC: 0.854
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82        85
#            1       0.75      0.69      0.72        58
#
#     accuracy                           0.78       143
#    macro avg       0.78      0.77      0.77       143
# weighted avg       0.78      0.78      0.78       143

# %% [markdown]
# With no further changes to our dataset features, we get a pretty solid accuracy. The model also performs well on our test dataset.
#
# Recall from earlier that we saw a skew in fare pricing, most obvious on our Cherbourg plot.
#
# From this, let's test a log transform and see if this performs better than our base model.

# %% [markdown]
# ### Logistical Regression with Log Transform

# %%
titanic_ml['fare_log'] = np.log1p(titanic_ml['fare'])
features_log = ['pclass', 'is_male', 'age', 'family_size', 'fare_log', 'embarked_c', 'embarked_q']

X_log = titanic_ml[features_log]
y_log = titanic_ml['survived']

X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(
    X_log, y_log, test_size=0.2, random_state=42, stratify=y_log)

scaler_log = StandardScaler()
X_train_log_scale = scaler_log.fit_transform(X_train_log)
X_test_log_scale  = scaler_log.transform(X_test_log)

lr_log = LogisticRegression(max_iter=1000, random_state=42)
lr_log.fit(X_train_log_scale, y_train_log)
y_pred_train_log  = lr_log.predict(X_train_log_scale)
y_pred_test_log = lr_log.predict(X_test_log_scale)
y_proba_train_log = lr_log.predict_proba(X_train_log_scale)[:,1]
y_proba_test_log = lr_log.predict_proba(X_test_log_scale)[:,1]

report_titanic(
    features_log, 
    "Logistical Regression w/Log Transform of Fare", 
    y_train_log, 
    y_pred_train_log, 
    y_proba_train_log,
    y_test_log, 
    y_pred_test_log,
    y_proba_test_log)
# Out:
# Results on regression on 'titanic_ml' Dataset with Logistical Regression w/Log Transform of Fare
#
#
# Using features = ['pclass', 'is_male', 'age', 'family_size', 'fare_log', 'embarked_c', 'embarked_q']
#
#
# Training dataset
#
# Accuracy: 0.794
# ROC-AUC: 0.859
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       339
#            1       0.76      0.71      0.74       230
#
#     accuracy                           0.79       569
#    macro avg       0.79      0.78      0.78       569
# weighted avg       0.79      0.79      0.79       569
#
# Testing dataset
#
# Accuracy: 0.776
# ROC-AUC: 0.857
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        85
#            1       0.72      0.72      0.72        58
#
#     accuracy                           0.78       143
#    macro avg       0.77      0.77      0.77       143
# ...

# %% [markdown]
# ### Grid Search Logistical Regression, Hyperparametrized?
#
# Let's try a different model to see if the performance is any better. We will also give C inputs for the model to test and see if it can hyperparametrize and perform well on the test dataset at the same time.

# %%
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}

titanic_grid = GridSearchCV(LogisticRegression(max_iter=1000, random_state = 42), param_grid, cv=5, scoring='roc_auc')
titanic_grid.fit(X_train_base_scale, y_train_base)
grid_best_est = titanic_grid.best_estimator_

print(f"Grid Search Best Parameters{titanic_grid.best_params_}", '\n')
print("Grid Search found these parameters for best regression", grid_best_est, '\n')

y_pred_train_grid = grid_best_est.predict(X_train_base_scale)
y_proba_train_grid = grid_best_est.predict_proba(X_train_base_scale)[:,1]
y_pred_test_grid = grid_best_est.predict(X_test_base_scale)
y_proba_test_grid = grid_best_est.predict_proba(X_test_base_scale)[:,1]
# Out:
# Grid Search Best Parameters{'C': 0.1}
#
# Grid Search found these parameters for best regression LogisticRegression(C=0.1, max_iter=1000, random_state=42)

# %%
report_titanic(
    "based on Hyperparameter Search",
    "Logistic Regression w/GridSearchCV's Best Model",
    y_train_base,
    y_pred_train_grid,
    y_proba_train_grid,
    y_test_base,
    y_pred_test_grid,
    y_proba_test_grid
)
# Out:
# Results on regression on 'titanic_ml' Dataset with Logistic Regression w/GridSearchCV's Best Model
#
#
# Using features = based on Hyperparameter Search
#
#
# Training dataset
#
# Accuracy: 0.793
# ROC-AUC: 0.858
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       339
#            1       0.77      0.70      0.73       230
#
#     accuracy                           0.79       569
#    macro avg       0.79      0.78      0.78       569
# weighted avg       0.79      0.79      0.79       569
#
# Testing dataset
#
# Accuracy: 0.790
# ROC-AUC: 0.856
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        85
#            1       0.75      0.72      0.74        58
#
#     accuracy                           0.79       143
#    macro avg       0.78      0.78      0.78       143
# weighted avg       0.79      0.79      0.79       143

# %% [markdown]
# ### Final: Support Vector Machine
#
# Finally, let's try a Support Vector Machine

# %%
titanic_svm = SVC(kernel='rbf', C=1, gamma='scale', probability=True, random_state=42)
titanic_svm.fit(X_train_base_scale, y_train_base)

y_pred_train_svm = titanic_svm.predict(X_train_base_scale)
y_pred_test_svm  = titanic_svm.predict(X_test_base_scale)
y_proba_train_svm = titanic_svm.predict_proba(X_train_base_scale)[:,1]
y_proba_test_svm  = titanic_svm.predict_proba(X_test_base_scale)[:,1]

# %%
report_titanic(
    features_baseline,
    "SVM (RBF Kernel)",
    y_train_base,
    y_pred_train_svm,
    y_proba_train_svm,
    y_test_base,
    y_pred_test_svm,
    y_proba_test_svm
)
# Out:
# Results on regression on 'titanic_ml' Dataset with SVM (RBF Kernel)
#
#
# Using features = ['pclass', 'is_male', 'age', 'family_size', 'fare', 'embarked_c', 'embarked_q']
#
#
# Training dataset
#
# Accuracy: 0.835
# ROC-AUC: 0.887
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87       339
#            1       0.90      0.66      0.76       230
#
#     accuracy                           0.83       569
#    macro avg       0.86      0.81      0.82       569
# weighted avg       0.85      0.83      0.83       569
#
# Testing dataset
#
# Accuracy: 0.825
# ROC-AUC: 0.863
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86        85
#            1       0.84      0.71      0.77        58
#
#     accuracy                           0.83       143
#    macro avg       0.83      0.81      0.81       143
# weighted avg       0.83      0.83      0.82       143

# %% [markdown]
# ### Model Evaluations - Confusion Matrix

# %%
models_dict = {
    "Logistical Regression": (y_pred_train_base, y_pred_test_base),
    "LR With Fare Transform": (y_pred_train_log, y_pred_test_log),
    "GridSearchCV Logistical Regression": (y_pred_train_grid, y_pred_test_grid),
    "SVM": (y_pred_train_svm, y_pred_test_svm)
}

def plot_cm_ax(ax, y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0,1], yticklabels=[0,1], ax=ax)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(title)

fig, axes = plt.subplots(2, 2, figsize=(12,10))
axes = axes.flatten()
for ax, (model_name, (y_pred_train, _)) in zip(axes, models_dict.items()):
    plot_cm_ax(ax, y_train_base, y_pred_train, f"{model_name} - Train")
plt.tight_layout()
plt.show()

# Plotting test confusion matrices
fig, axes = plt.subplots(2, 2, figsize=(12,10))
axes = axes.flatten()
for ax, (model_name, (_, y_pred_test)) in zip(axes, models_dict.items()):
    plot_cm_ax(ax, y_test_base, y_pred_test, f"{model_name} - Test")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion
#
# At a baseline, we were able to acceptably predict survival rates on the titanic. Our most performant model was SVM.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# Crew members are not accounted for in the dataset, so their survival rates will not be accounted for or modeled accurately. Additionally, our analysis of the tragedy will be restricted to numeric and categorical data, which will not take into account any emotional and psychological factors in play.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# It is well-known that a "women and children first" policy was implemented in evacuating the Titanic, causing an irreversible categorical change that will affect survival rates. We are aware of this effect and are actively going to be monitoring its effects, and will reserve any conclusions we make on survival rates with the skew in mind.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# The correlations that we are exploring are more the result of contemporary discriminatory or otherwise biased views i.e. valuing women and children more, rather than the characteristics of the passengers themselves which we are measuring. The included visualizations are based on measurable and/or clearly identifiable passenger characteristics to generalize and identify larger trends. We will also reserve conclusions to within reason, i.e. any conclusion that "women and children were more likely to survive" will be carefully ftamed with its context (WCS policy called, not enough lifeboats) and the acknowledgement that both regulation and policy on cruise ships have changed since 1912.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# We have ensured that this dataset does not include passenger names or otherwise unnecessary PII.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# While we are using proxy variables (Ticket Class and Fare to proxy for wealth/social status), we are aware and are actively categorizing them to test the biases that these variables introduce into models. We will also keep in mind that this bias should be taken into account and checked for most if not all EDA we perform.
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# We will be subsetting our own data, and if time permits, use a unique enough and compatible enough dataset to confirm performance monitoring.
#
# We will also be disclaiming that the conclusions from this data, and by extension, the Titanic, have already been used for many policy changes, engineering design changes, and also that the Titanic is considered an engineering marvel, meaning its protocol and structure are uniquely different from its own ships from its time, let alone ships today. Because of this, we will comfortably restrict our conclusions to apply most likely to other Olympic Class vessels and Cruise ships sailing on or around the year 1914.
#
# The use of model accuracy maintenance
#
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# While the models themselves should be relatively flexible enough to be useful for other datasets, we will carefully monitor the conclusions made using our findings, so as to acknowledge the uniqueness and datedness of the Titanic's situation. Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Discussion and Conclusion
#
# In conclusion, our analysis of this data presents compelling evidence that the characteristics of passengers on the titanic, particularly class and gender, played a large role in determining survivability. Through several different approaches including linear regression and analysis of individual and subgroup characteristic patterns we have repeatedly found the same result: women and higher class passengers had a much higher rate of survival, while age had a minor influence though its effects were less consistent.
#
# This aligns perfectly with the patterns that we predicted in the background section. The "Women and Children First" norm as well as the valuing of socioeconomic status directly contributed to these restults. The increase of survivability in first class passengers demonstrates that they had favorable/safer locations on the ship as well as more access to important resources like life jackets or life boats. Thus, our EDA reinforces the fact that the concurrent gender roles and societal norms had a measurable effect on passenger survivability.
#
# Age showed some trends, but the overall effect was weaker and depended on modeling. This could be due to the fact that age likly interacts strongly with other characteristics like number of relatives onboard and gender. For example, the "women and children first" rule likely favored children that were onboard and together with their mothers at the time of the accident. So not all characteristics are cut and dry, some need to be observed in relation to other characteristics to have their effect be measurable and consistent.
#
# Our study had a few limitations, the largest of which being that the dataset only included passengers and not crew members (or potential stowaways); this could introduce sampling bias. Additionally, some of the rows were incomplete requiring us to remove them from our dataset and potentially affect the results of our analysis. There are also some characteristics that would have provided a much clearer picture that were not in the dataset, like the location of the passenger's cabin or their actual socioeconomic status. With some more detailed data we could paint a more accurate picture of what actually contributed to survivability. But of course, this research is up for scrutiny, please see the methods above and come to your own conclusion on the validity of the methods and findings.
